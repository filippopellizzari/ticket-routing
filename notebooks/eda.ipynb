# %%
import os
import pandas as pd
ROOT_DIR = '/Users/filippopellizzari/code/ticket-routing/'
os.chdir(ROOT_DIR)

# %%
df = pd.read_parquet("data/complaints_labeled.parquet")

# %%
df
# Out:
#                 tags zip_code complaint_id  \
# 0               None    90301      3211475
# 1      Servicemember    319XX      3229299
# 2               None    77069      3199379
# 3               None    48066      2673060
# 4               None    10473      3203545
# ...              ...      ...          ...
# 78307           None    074XX      3156336
# 78308           None    08857      3105617
# 78309           None    934XX      3091984
# 78310           None    923XX      3133355
# 78311           None     None      3110963
#
#                                                    issue  \
# 0                      Attempts to collect debt not owed
# 1                        Written notification about debt
# 2                     Other features, terms, or problems
# 3                         Trouble during payment process
# 4                                       Fees or interest
# ...                                                  ...
# 78307  Applying for a mortgage or refinancing an exis...
# 78308                                 Closing an account
# 78309                 Other features, terms, or problems
# 78310  Problem with a lender or other company chargin...
# 78311                 Other features, terms, or problems
#
#                    date_received state consumer_disputed  \
# 0      2019-04-13T12:00:00-05:00    CA               N/A
# 1      2019-05-01T12:00:00-05:00    GA               N/A
# 2      2019-04-02T12:00:00-05:00    TX               N/A
# 3      2017-09-13T12:00:00-05:00    MI               N/A
# 4      2019-04-05T12:00:00-05:00    NY               N/A
# ...                          ...   ...               ...
# 78307  2019-02-19T12:00:00-05:00    NJ               N/A
# 78308  2018-12-20T12:00:00-05:00    NJ               N/A
# 78309  2018-12-05T12:00:00-05:00    CA               N/A
# 78310  2019-01-25T12:00:00-05:00    CA               N/A
# 78311  2018-12-27T12:00:00-05:00    PA               N/A
#
#                            product             company_response submitted_via  \
# 0                  Debt collection      Closed with explanation           Web
# 1                  Debt collection      Closed with explanation           Web
# 2      Credit card or prepaid card      Closed with explanation           Web
# 3                         Mortgage      Closed with explanation           Web
# 4      Credit card or prepaid card      Closed with explanation      Referral
# ...                            ...                          ...           ...
# 78307                     Mortgage      Closed with explanation           Web
# 78308  Checking or savings account      Closed with explanation           Web
# 78309  Credit card or prepaid card  Closed with monetary relief           Web
# 78310  Checking or savings account      Closed with explanation           Web
# 78311  Credit card or prepaid card  Closed with monetary relief           Web
#
#             date_sent_to_company                                 sub_product  \
# 0      2019-04-13T12:00:00-05:00                            Credit card debt
# 1      2019-05-01T12:00:00-05:00                            Credit card debt
# 2      2019-04-02T12:00:00-05:00  General-purpose credit card or charge card
# 3      2017-09-14T12:00:00-05:00                  Conventional home mortgage
# 4      2019-04-05T12:00:00-05:00  General-purpose credit card or charge card
# ...                          ...                                         ...
# 78307  2019-02-19T12:00:00-05:00                  Conventional home mortgage
# 78308  2018-12-21T12:00:00-05:00                            Checking account
# 78309  2018-12-05T12:00:00-05:00  General-purpose credit card or charge card
# 78310  2019-01-25T12:00:00-05:00                            Checking account
# 78311  2018-12-27T12:00:00-05:00  General-purpose credit card or charge card
#
#       timely                            complaint_what_happened  \
# 0        Yes
# 1        Yes  Good morning my name is XXXX XXXX and I apprec...
# 2        Yes  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3        Yes
# 4        Yes
# ...      ...                                                ...
# 78307    Yes
# 78308    Yes
# 78309    Yes  On Wednesday, XX/XX/XXXX I called Chas, my XXX...
# 78310    Yes  I am not familiar with XXXX pay and did not un...
# 78311    Yes  I have had flawless credit for 30 yrs. I've ha...
#
#                                               sub_issue  \
# 0                                     Debt is not yours
# 1      Didn't receive enough information to verify debt
# 2                 Problem with rewards from credit card
# 3                                                  None
# 4                             Charged too much interest
# ...                                                 ...
# 78307                                              None
# 78308            Funds not received from closed account
# 78309                                     Other problem
# 78310                    Transaction was not authorized
# 78311                     Problem with balance transfer
#
#       consumer_consent_provided  forwarding_days  \
# 0          Consent not provided                0
# 1              Consent provided                0
# 2              Consent provided                0
# 3          Consent not provided                1
# 4                           N/A                0
# ...                         ...              ...
# 78307                     Other                0
# 78308      Consent not provided                1
# 78309          Consent provided                0
# 78310          Consent provided                0
# 78311          Consent provided                0
#
#                                                     text  label       category
# 0      Debt collection Credit card debt Attempts to c...      0         others
# 1      Debt collection Credit card debt Written notif...      0         others
# 2      Credit card or prepaid card General-purpose cr...      0         others
# 3      Mortgage Conventional home mortgage Trouble du...      1       mortgage
# 4      Credit card or prepaid card General-purpose cr...      3    credit_card
# ...                                                  ...    ...            ...
# 78307  Mortgage Conventional home mortgage Applying f...      1       mortgage
# 78308  Checking or savings account Checking account C...      4  theft_dispute
# 78309  Credit card or prepaid card General-purpose cr...      0         others
# 78310  Checking or savings account Checking account P...      0         others
# 78311  Credit card or prepaid card General-purpose cr...      0         others
#
# [67742 rows x 20 columns]
